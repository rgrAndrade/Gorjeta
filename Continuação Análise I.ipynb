# %% [markdown]
# # Continuação Análise I

# %% [markdown]
# ## Criando o Campo Porcentagem

# %%
import pandas as pd
gorjetas = pd.read_csv('arquivo/gorjetas.csv')
gorjetas.sample(4)
# Out:
#       valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 200            18.71     4.00       Sim   Quita-Feira      Almoço
# 22             15.77     2.23       Não        Sábado      Jantar
# 197            43.11     5.00       Sim   Quita-Feira      Almoço
# 154            19.77     2.00       Não       Domingo      Jantar
#
#      total_de_pessoas
# 200                 3
# 22                  2
# 197                 4
# 154                 4

# %%
import seaborn as sns

# %%
valor_gorjeta = sns.scatterplot(x=' valor_da_conta', y= 'gorjeta', data=gorjetas)

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas[' valor_da_conta']
gorjetas.sample(4).round(2)
# Out:
#       valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 71             17.07      3.0       Não        Sábado      Jantar
# 61             13.81      2.0       Sim        Sábado      Jantar
# 137            14.15      2.0       Não   Quita-Feira      Almoço
# 67              3.07      1.0       Sim        Sábado      Jantar
#
#      total_de_pessoas  porcentagem
# 71                  3         0.18
# 61                  2         0.14
# 137                 2         0.14
# 67                  1         0.33

# %%
porcentagem_conta = sns.scatterplot(x=' valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# ### Visualmente o valor da conta não e proporcional ao valor da gorjeta

# %%
porcentagem_conta_linha = sns.relplot(x=' valor_da_conta', y='porcentagem', kind='line', data=gorjetas)

# %%
sns.lmplot(x=' valor_da_conta', y='porcentagem', data=gorjetas)
