# %% [markdown]
# # Analise II - Sobremesa

# %%
import pandas as pd
import seaborn as sns

# %%
gorjetas = pd.read_csv('arquivo/gorjetas.csv')
gorjetas.head()
# Out:
#     valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0            16.99     1.01       Não       Domingo      Jantar
# 1            10.34     1.66       Não       Domingo      Jantar
# 2            21.01     3.50       Não       Domingo      Jantar
# 3            23.68     3.31       Não       Domingo      Jantar
# 4            24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas[gorjetas.sobremesa=='Sim'].describe()
# Out:
#         valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count        93.000000  93.000000         93.000000    93.000000
# mean         20.756344   3.008710          2.408602     0.163196
# std           9.832154   1.401468          0.810751     0.085119
# min           3.070000   1.000000          1.000000     0.035638
# 25%          13.420000   2.000000          2.000000     0.106771
# 50%          17.920000   3.000000          2.000000     0.153846
# 75%          26.860000   3.680000          3.000000     0.195059
# max          50.810000  10.000000          5.000000     0.710345

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=gorjetas)

# %%
sns.relplot(x=' valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x=' valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.lmplot(x=' valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
 sns.lmplot(x=' valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x=' valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', kind='line', data=gorjetas)

# %% [markdown]
# ### Existe uma diferença visual entre os que pedem sobremesa e os que não pedem no valor da gorjeta

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# H<sup>null</sup>
# >**A distribuição da taxa da gorjeta é a mesma nos dois grupos**

# %% [markdown]
# H<sup>alt</sup>
# >**A distrinuiçao da taxa da gorjeta não é a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
sem_sobremesa
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
#          ...
# 235    0.124131
# 238    0.130338
# 239    0.203927
# 242    0.098204
# 243    0.159744
# Name: porcentagem, Length: 151, dtype: float64

# %%
r = ranksums(sobremesa, sem_sobremesa)
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.5601068283978767

# %% [markdown]
# H<sup>null</sup>
# >**A distribuição da taxa da gorjeta é a mesma nos dois grupos**
